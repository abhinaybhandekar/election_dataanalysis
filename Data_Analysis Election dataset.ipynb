# %% [markdown]
# Loading the Indian Election dataset containing 2263 records and printing the first 5 records

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
file_path ="/content/ELECTION DATASET.csv"
df = pd.read_csv('/content/ELECTION DATASET.csv', delimiter=',', encoding='utf-8')
df
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER  CRIMINAL CASES   AGE CATEGORY      EDUCATION  \
# 0     Lotus   MALE            52.0  52.0       ST      12th Pass
# 1       Car   MALE             0.0  54.0       ST  Post Graduate
# 2      Hand   MALE             3.0  52.0       ST      12th Pass
# 3       NaN    NaN             NaN   NaN      NaN            NaN
# 4     Lotus   MALE             5.0  58.0       SC      Doctorate
# ...     ...    ...             ...   ...      ...            ...
# 2258   SHIP   MALE             0.0  43.0  GENERAL  Post Graduate
# 2259    Car   MALE            18.0  63.0  GENERAL       Graduate
# 2260   Hand   MALE             0.0  49.0  GENERAL  Post Graduate
# 2261  Lotus   MALE             3.0  47.0  GENERAL      12th Pass
# 2262    NaN    NaN             NaN   NaN      NaN            NaN
#
#                                 ASSETS                  LIABILITIES  \
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 3                                  NaN                          NaN
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# ...                                ...                          ...
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
# 2262                               NaN                          NaN
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            376892           482       377374
# 1            318665           149       318814
# 2            314057           181       314238
# 3             13030             6        13036
# 4            644459          2416       646875
# ...             ...           ...          ...
# 2258          14661            25        14686
# 2259         434066           178       434244
# 2260         427900           115       428015
# 2261         138731           216       138947
# 2262          11138             2        11140
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0                                 25.330684
# 1                                 21.399929
# 2                                 21.092771
# 3                                  0.875023
# 4                                 33.383823
# ...                                     ...
# 2258                               0.766419
# 2259                              28.975369
# 2260                              28.559732
# 2261                               9.271379
# 2262                               0.743328
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 3                                      1.225214         1489790
# 4                                     56.464615         1937690
# ...                                         ...             ...
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
# 2262                                   1.066535         1498666
#
# [2263 rows x 19 columns]

# %%
a=df.isnull().mean()
b=df.dtypes
result = pd.concat([a, b], axis=1)
result.columns = ['Missing percentages', 'Data Type']

print(result)
# Out:
#                                            Missing percentages Data Type
# STATE                                                 0.000000    object
# CONSTITUENCY                                          0.000000    object
# NAME                                                  0.000000    object
# WINNER                                                0.000000     int64
# PARTY                                                 0.000000    object
# SYMBOL                                                0.108263    object
# GENDER                                                0.108263    object
# CRIMINAL CASES                                        0.117985   float64
# AGE                                                   0.108263   float64
# CATEGORY                                              0.108263    object
# EDUCATION                                             0.117985    object
# ASSETS                                                0.117985    object
# LIABILITIES                                           0.117985    object
# GENERAL VOTES                                         0.000000     int64
# POSTAL VOTES                                          0.000000     int64
# TOTAL VOTES                                           0.000000     int64
# OVER TOTAL ELECTORS \nIN CONSTITUENCY                 0.000000   float64
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY             0.000000   float64
# TOTAL ELECTORS                                        0.000000     int64

# %% [markdown]
# We find that "NOTA" is not a good attribute so we deleted all the records containing NOTA, so all the missing values are deleted using complete case analysis (CCA)

# %%
total_rows_with_NOTA = (df['NAME'] == 'NOTA').sum()
print("Records containing 'NOTA' in the 'NAME' column: " + str(total_rows_with_NOTA))

df_new = df[df['NAME'] != 'NOTA']

total_rows_with_NOTA_filtered = (df_new['NAME'] == 'NOTA').sum()
print("New dataset records containing 'NOTA' in the 'NAME' column: " + str(total_rows_with_NOTA_filtered))
# Out:
# Records containing 'NOTA' in the 'NAME' column: 245
# New dataset records containing 'NOTA' in the 'NAME' column: 0

# %%
df_new
# Out:
#               STATE     CONSTITUENCY                    NAME  WINNER  PARTY  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO       1    BJP
# 1         Telangana         ADILABAD            Godam Nagesh       0    TRS
# 2         Telangana         ADILABAD           RATHOD RAMESH       0    INC
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel       1    BJP
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni       0    BSP
# ...             ...              ...                     ...     ...    ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede       0  PHJSP
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod       0    IND
# 2259      Telangana        ZAHIRABAD               B.B.PATIL       1    TRS
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO       0    INC
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY       0    BJP
#
#         SYMBOL  GENDER  CRIMINAL CASES   AGE CATEGORY      EDUCATION  \
# 0        Lotus    MALE            52.0  52.0       ST      12th Pass
# 1          Car    MALE             0.0  54.0       ST  Post Graduate
# 2         Hand    MALE             3.0  52.0       ST      12th Pass
# 4        Lotus    MALE             5.0  58.0       SC      Doctorate
# 5     Elephant    MALE             0.0  47.0       SC  Post Graduate
# ...        ...     ...             ...   ...      ...            ...
# 2257   Whistle  FEMALE             0.0  28.0  GENERAL      10th Pass
# 2258      SHIP    MALE             0.0  43.0  GENERAL  Post Graduate
# 2259       Car    MALE            18.0  63.0  GENERAL       Graduate
# 2260      Hand    MALE             0.0  49.0  GENERAL  Post Graduate
# 2261     Lotus    MALE             3.0  47.0  GENERAL      12th Pass
#
#                                 ASSETS                  LIABILITIES  \
# 0            Rs 30,99,414\n ~ 30 Lacs+      Rs 2,31,450\n ~ 2 Lacs+
# 1          Rs 1,84,77,888\n ~ 1 Crore+      Rs 8,47,000\n ~ 8 Lacs+
# 2          Rs 3,64,91,000\n ~ 3 Crore+  Rs 1,53,00,000\n ~ 1 Crore+
# 4          Rs 7,42,74,036\n ~ 7 Crore+    Rs 86,06,522\n ~ 86 Lacs+
# 5        Rs 13,37,84,385\n ~ 13 Crore+  Rs 2,22,51,891\n ~ 2 Crore+
# ...                                ...                          ...
# 2257         Rs 11,68,500\n ~ 11 Lacs+         Rs 9,000\n ~ 9 Thou+
# 2258         Rs 48,90,000\n ~ 48 Lacs+    Rs 10,20,000\n ~ 10 Lacs+
# 2259  Rs 1,28,78,51,556\n ~ 128 Crore+  Rs 1,15,35,000\n ~ 1 Crore+
# 2260     Rs 90,36,63,001\n ~ 90 Crore+                     Rs 0\n ~
# 2261       Rs 5,85,77,327\n ~ 5 Crore+    Rs 52,50,000\n ~ 52 Lacs+
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            376892           482       377374
# 1            318665           149       318814
# 2            314057           181       314238
# 4            644459          2416       646875
# 5            434199          1130       435329
# ...             ...           ...          ...
# 2257          20563            57        20620
# 2258          14661            25        14686
# 2259         434066           178       434244
# 2260         427900           115       428015
# 2261         138731           216       138947
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0                                 25.330684
# 1                                 21.399929
# 2                                 21.092771
# 4                                 33.383823
# 5                                 22.466390
# ...                                     ...
# 2257                               1.076097
# 2258                               0.766419
# 2259                              28.975369
# 2260                              28.559732
# 2261                               9.271379
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 4                                     56.464615         1937690
# 5                                     37.999125         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
#
# [2018 rows x 19 columns]

# %% [markdown]
# Comparision of graphs before and removing records containing "NOTA"

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numerical_attributes = [
    column for column in df.columns if pd.api.types.is_numeric_dtype(df[column])]


for column in numerical_attributes:
    plt.figure(figsize=(4, 2))
    sns.histplot(data=df, x=column, kde=True)
    sns.histplot(data=df_new, x=column, kde=True)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
df_new.isnull().mean()
# Out:
# STATE                                        0.000000
# CONSTITUENCY                                 0.000000
# NAME                                         0.000000
# WINNER                                       0.000000
# PARTY                                        0.000000
# SYMBOL                                       0.000000
# GENDER                                       0.000000
# CRIMINAL CASES                               0.010902
# AGE                                          0.000000
# CATEGORY                                     0.000000
# EDUCATION                                    0.010902
# ASSETS                                       0.010902
# LIABILITIES                                  0.010902
# GENERAL VOTES                                0.000000
# POSTAL VOTES                                 0.000000
# TOTAL VOTES                                  0.000000
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0.000000
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0.000000
# TOTAL ELECTORS                               0.000000
# dtype: float64

# %% [markdown]
# converting EDUCATION, ASSETS and LIABILITIES into numerical data

# %%
character_to_split = '\n'
df_new['ASSETS'] = df_new['ASSETS'].str.split(character_to_split).str[0]
df_new['LIABILITIES'] = df_new['LIABILITIES'].str.split(character_to_split).str[0]
df_new["ASSETS"] = pd.to_numeric(df_new["ASSETS"].str.replace("Rs ", "").str.replace(",", "").str.strip(), errors="coerce")
df_new["LIABILITIES"] = pd.to_numeric(df_new["LIABILITIES"].str.replace("Rs ", "").str.replace(",", "").str.strip(), errors="coerce")
df_new
# Out:
# <ipython-input-66-53e9cd64dece>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['ASSETS'] = df_new['ASSETS'].str.split(character_to_split).str[0]
# <ipython-input-66-53e9cd64dece>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['LIABILITIES'] = df_new['LIABILITIES'].str.split(character_to_split).str[0]
# <ipython-input-66-53e9cd64dece>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["ASSETS"] = pd.to_numeric(df_new["ASSETS"].str.replace("Rs ", "").str.replace(",", "").str.strip(), errors="coerce")
# <ipython-input-66-53e9cd64dece>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["LIABILITIES"] = pd.to_numeric(df_new["LIABILITIES"].str.replace("Rs ", "").str.replace(",", "").str.strip(), errors="coerce")
#               STATE     CONSTITUENCY                    NAME  WINNER  PARTY  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO       1    BJP
# 1         Telangana         ADILABAD            Godam Nagesh       0    TRS
# 2         Telangana         ADILABAD           RATHOD RAMESH       0    INC
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel       1    BJP
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni       0    BSP
# ...             ...              ...                     ...     ...    ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede       0  PHJSP
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod       0    IND
# 2259      Telangana        ZAHIRABAD               B.B.PATIL       1    TRS
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO       0    INC
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY       0    BJP
#
#         SYMBOL  GENDER  CRIMINAL CASES   AGE CATEGORY      EDUCATION  \
# 0        Lotus    MALE            52.0  52.0       ST      12th Pass
# 1          Car    MALE             0.0  54.0       ST  Post Graduate
# 2         Hand    MALE             3.0  52.0       ST      12th Pass
# 4        Lotus    MALE             5.0  58.0       SC      Doctorate
# 5     Elephant    MALE             0.0  47.0       SC  Post Graduate
# ...        ...     ...             ...   ...      ...            ...
# 2257   Whistle  FEMALE             0.0  28.0  GENERAL      10th Pass
# 2258      SHIP    MALE             0.0  43.0  GENERAL  Post Graduate
# 2259       Car    MALE            18.0  63.0  GENERAL       Graduate
# 2260      Hand    MALE             0.0  49.0  GENERAL  Post Graduate
# 2261     Lotus    MALE             3.0  47.0  GENERAL      12th Pass
#
#             ASSETS  LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0     3.099414e+06     231450.0         376892           482       377374
# 1     1.847789e+07     847000.0         318665           149       318814
# 2     3.649100e+07   15300000.0         314057           181       314238
# 4     7.427404e+07    8606522.0         644459          2416       646875
# 5     1.337844e+08   22251891.0         434199          1130       435329
# ...            ...          ...            ...           ...          ...
# 2257  1.168500e+06       9000.0          20563            57        20620
# 2258  4.890000e+06    1020000.0          14661            25        14686
# 2259  1.287852e+09   11535000.0         434066           178       434244
# 2260  9.036630e+08          0.0         427900           115       428015
# 2261  5.857733e+07    5250000.0         138731           216       138947
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0                                 25.330684
# 1                                 21.399929
# 2                                 21.092771
# 4                                 33.383823
# 5                                 22.466390
# ...                                     ...
# 2257                               1.076097
# 2258                               0.766419
# 2259                              28.975369
# 2260                              28.559732
# 2261                               9.271379
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 4                                     56.464615         1937690
# 5                                     37.999125         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
#
# [2018 rows x 19 columns]

# %% [markdown]
# Handling missing values using different imputations

# %%
import pandas as pd
import matplotlib.pyplot as plt
mean_value = df_new["CRIMINAL CASES"].mean()
median_value = df_new["CRIMINAL CASES"].median()
mode_value=df_new["CRIMINAL CASES"].mode()

print("mean value: "+str(mean_value))
print("median value: "+str(median_value))
print("mode value: "+str(mode_value))
# Impute missing values with the mean
df_mean_imputed = df_new["CRIMINAL CASES"].fillna(mean_value)
# Impute missing values with the median
df_median_imputed = df_new["CRIMINAL CASES"].fillna(median_value)
# Impute missing values with the mode
df_mode_imputed = df_new["CRIMINAL CASES"].fillna(mode_value)

# Create subplots for histograms
plt.subplot(2,2,1)
plt.hist(df_new["CRIMINAL CASES"], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of CRIMINAL CASES')
plt.xlabel('CRIMINAL CASES')
plt.ylabel('Frequency')
# Histogram after mean imputation
plt.subplot(2, 2, 2)
plt.hist(df_mean_imputed, bins=20, color='blue', alpha=0.7)
plt.title('Histogram (Mean Imputation)')
plt.xlabel('CRIMINAL CASES')
plt.ylabel('Frequency')


# Histogram after median imputation
plt.subplot(2, 2, 3)
plt.hist(df_median_imputed, bins=20, color='green', alpha=0.7)
plt.title('Histogram (Median Imputation)')
plt.xlabel('CRIMINAL CASES')
plt.ylabel('Frequency')


# Histogram after mode imputation
plt.subplot(2, 2, 4)
plt.hist(df_mode_imputed, bins=20, color='red')
plt.title('Histogram (mode Imputation)')
plt.xlabel('CRIMINAL CASES')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# mean value: 1.4699398797595191
# median value: 0.0
# mode value: 0    0.0
# Name: CRIMINAL CASES, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df_new'

# Calculate the mean and median of the "ASSETS" column
mean_value = df_new["ASSETS"].mean()
median_value = df_new["ASSETS"].median()
mode_value = df_new["ASSETS"].mode().iloc[0]

print("mean value: " + str(mean_value))
print("median value: " + str(median_value))
print("mode value: " + str(mode_value))

# Impute missing values with the mean
df_mean_imputed = df_new["ASSETS"].fillna(mean_value)

# Impute missing values with the median
df_median_imputed = df_new["ASSETS"].fillna(median_value)

# Impute missing values with the mode
df_mode_imputed = df_new["ASSETS"].fillna(mode_value)

# Create subplots for histograms
plt.subplot(2, 2, 1)
plt.hist(df_new["ASSETS"], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of ASSETS')
plt.xlabel('ASSETS')
plt.ylabel('Frequency')

# Histogram after mean imputation
plt.subplot(2, 2, 2)
plt.hist(df_mean_imputed, bins=20, color='blue', alpha=0.7)
plt.title('Histogram (Mean Imputation)')
plt.xlabel('ASSETS')
plt.ylabel('Frequency')

# Histogram after median imputation
plt.subplot(2, 2, 3)
plt.hist(df_median_imputed, bins=20, color='green', alpha=0.7)
plt.title('Histogram (Median Imputation)')
plt.xlabel('ASSETS')
plt.ylabel('Frequency')

# Histogram after mode imputation
plt.subplot(2, 2, 4)
plt.hist(df_mode_imputed, bins=20, color='red', alpha=0.7)
plt.title('Histogram (Mode Imputation)')
plt.xlabel('ASSETS')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# mean value: 133302359.65411647
# median value: 24622912.5
# mode value: 47000.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df_new'

# Calculate the mean, median, and mode of the "LIABILITIES" column
mean_value = df_new["LIABILITIES"].mean()
median_value = df_new["LIABILITIES"].median()
mode_value = df_new["LIABILITIES"].mode()

print("Mean value: " + str(mean_value))
print("Median value: " + str(median_value))
print("Mode value: " + str(mode_value))

# Impute missing values with the mean
df_mean_imputed = df_new["LIABILITIES"].fillna(mean_value)

# Impute missing values with the median
df_median_imputed = df_new["LIABILITIES"].fillna(median_value)

# Impute missing values with the mode
df_mode_imputed = df_new["LIABILITIES"].fillna(mode_value)


# Histogram of "LIABILITIES" before imputation
plt.subplot(2, 2, 1)
plt.hist(df_new["LIABILITIES"], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of LIABILITIES (Before Imputation)')
plt.xlabel('LIABILITIES')
plt.ylabel('Frequency')

# Histogram after mean imputation
plt.subplot(2, 2, 2)
plt.hist(df_mean_imputed, bins=20, color='green', alpha=0.7)
plt.title('Histogram (Mean Imputation)')
plt.xlabel('LIABILITIES')
plt.ylabel('Frequency')

# Histogram after median imputation
plt.subplot(2, 2, 3)
plt.hist(df_median_imputed, bins=20, color='red', alpha=0.7)
plt.title('Histogram (Median Imputation)')
plt.xlabel('LIABILITIES')
plt.ylabel('Frequency')

# Histogram after mode imputation
plt.subplot(2, 2, 4)
plt.hist(df_mode_imputed, bins=20, color='purple', alpha=0.7)
plt.title('Histogram (Mode Imputation)')
plt.xlabel('LIABILITIES')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Mean value: 19966159.63659148
# Median value: 953336.0
# Mode value: 0    0.0
# Name: LIABILITIES, dtype: float64

# %% [markdown]
# Encoding Categorical Data

# %% [markdown]
# 1)LABEL ENCODING for states and constituency

# %%
label_encoder = LabelEncoder()
df_new['state_label'] = label_encoder.fit_transform(df_new['STATE'])
df_new['constituency_label'] = label_encoder.fit_transform(df_new['CONSTITUENCY'])
column_order = ['STATE', 'state_label',"CONSTITUENCY","constituency_label"] + [col for col in df.columns if col not in ['STATE', 'state_label',"CONSTITUENCY","constituency_label"]]
df_new = df_new[column_order]
df_new
# Out:
# <ipython-input-70-55a43ad90ff2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['state_label'] = label_encoder.fit_transform(df_new['STATE'])
# <ipython-input-70-55a43ad90ff2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['constituency_label'] = label_encoder.fit_transform(df_new['CONSTITUENCY'])
#               STATE  state_label     CONSTITUENCY  constituency_label  \
# 0         Telangana           31         ADILABAD                   0
# 1         Telangana           31         ADILABAD                   0
# 2         Telangana           31         ADILABAD                   0
# 4     Uttar Pradesh           33             AGRA                   1
# 5     Uttar Pradesh           33             AGRA                   1
# ...             ...          ...              ...                 ...
# 2257    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2258    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2259      Telangana           31        ZAHIRABAD                 538
# 2260      Telangana           31        ZAHIRABAD                 538
# 2261      Telangana           31        ZAHIRABAD                 538
#
#                         NAME  WINNER  PARTY    SYMBOL  GENDER  CRIMINAL CASES  \
# 0             SOYAM BAPU RAO       1    BJP     Lotus    MALE            52.0
# 1               Godam Nagesh       0    TRS       Car    MALE             0.0
# 2              RATHOD RAMESH       0    INC      Hand    MALE             3.0
# 4      Satyapal Singh Baghel       1    BJP     Lotus    MALE             5.0
# 5           Manoj Kumar Soni       0    BSP  Elephant    MALE             0.0
# ...                      ...     ...    ...       ...     ...             ...
# 2257  Vaishali Sudhakar Yede       0  PHJSP   Whistle  FEMALE             0.0
# 2258      Anil Jayram Rathod       0    IND      SHIP    MALE             0.0
# 2259               B.B.PATIL       1    TRS       Car    MALE            18.0
# 2260         MADAN MOHAN RAO       0    INC      Hand    MALE             0.0
# 2261      BANALA LAXMA REDDY       0    BJP     Lotus    MALE             3.0
#
#       ...  CATEGORY      EDUCATION        ASSETS  LIABILITIES  GENERAL VOTES  \
# 0     ...        ST      12th Pass  3.099414e+06     231450.0         376892
# 1     ...        ST  Post Graduate  1.847789e+07     847000.0         318665
# 2     ...        ST      12th Pass  3.649100e+07   15300000.0         314057
# 4     ...        SC      Doctorate  7.427404e+07    8606522.0         644459
# 5     ...        SC  Post Graduate  1.337844e+08   22251891.0         434199
# ...   ...       ...            ...           ...          ...            ...
# 2257  ...   GENERAL      10th Pass  1.168500e+06       9000.0          20563
# 2258  ...   GENERAL  Post Graduate  4.890000e+06    1020000.0          14661
# 2259  ...   GENERAL       Graduate  1.287852e+09   11535000.0         434066
# 2260  ...   GENERAL  Post Graduate  9.036630e+08          0.0         427900
# 2261  ...   GENERAL      12th Pass  5.857733e+07    5250000.0         138731
#
#       POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0              482       377374                              25.330684
# 1              149       318814                              21.399929
# 2              181       314238                              21.092771
# 4             2416       646875                              33.383823
# 5             1130       435329                              22.466390
# ...            ...          ...                                    ...
# 2257            57        20620                               1.076097
# 2258            25        14686                               0.766419
# 2259           178       434244                              28.975369
# 2260           115       428015                              28.559732
# 2261           216       138947                               9.271379
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 4                                     56.464615         1937690
# 5                                     37.999125         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
#
# [2018 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

state_label_counts = df_new['state_label'].value_counts()

# Extract the state labels (x-axis) and their corresponding frequencies (y-axis)
state_labels = state_label_counts.index
frequencies = state_label_counts.values

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(state_labels, frequencies)
plt.xlabel('State Label')
plt.ylabel('Frequency')
plt.title('Frequency of State Labels')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability if needed
plt.tight_layout()  # Ensure all labels fit in the plot
plt.show()

# %% [markdown]
# FREQUENCY ENCODING for party

# %%
party_frequency = df_new['PARTY'].value_counts(normalize=True)
df_new['PARTY'] = df_new['PARTY'].map(party_frequency)
df_new
# Out:
#               STATE  state_label     CONSTITUENCY  constituency_label  \
# 0         Telangana           31         ADILABAD                   0
# 1         Telangana           31         ADILABAD                   0
# 2         Telangana           31         ADILABAD                   0
# 4     Uttar Pradesh           33             AGRA                   1
# 5     Uttar Pradesh           33             AGRA                   1
# ...             ...          ...              ...                 ...
# 2257    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2258    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2259      Telangana           31        ZAHIRABAD                 538
# 2260      Telangana           31        ZAHIRABAD                 538
# 2261      Telangana           31        ZAHIRABAD                 538
#
#                         NAME  WINNER     PARTY    SYMBOL  GENDER  \
# 0             SOYAM BAPU RAO       1  0.208127     Lotus    MALE
# 1               Godam Nagesh       0  0.008424       Car    MALE
# 2              RATHOD RAMESH       0  0.204658      Hand    MALE
# 4      Satyapal Singh Baghel       1  0.208127     Lotus    MALE
# 5           Manoj Kumar Soni       0  0.080773  Elephant    MALE
# ...                      ...     ...       ...       ...     ...
# 2257  Vaishali Sudhakar Yede       0  0.000496   Whistle  FEMALE
# 2258      Anil Jayram Rathod       0  0.099604      SHIP    MALE
# 2259               B.B.PATIL       1  0.008424       Car    MALE
# 2260         MADAN MOHAN RAO       0  0.204658      Hand    MALE
# 2261      BANALA LAXMA REDDY       0  0.208127     Lotus    MALE
#
#       CRIMINAL CASES  ...  CATEGORY      EDUCATION        ASSETS  LIABILITIES  \
# 0               52.0  ...        ST      12th Pass  3.099414e+06     231450.0
# 1                0.0  ...        ST  Post Graduate  1.847789e+07     847000.0
# 2                3.0  ...        ST      12th Pass  3.649100e+07   15300000.0
# 4                5.0  ...        SC      Doctorate  7.427404e+07    8606522.0
# 5                0.0  ...        SC  Post Graduate  1.337844e+08   22251891.0
# ...              ...  ...       ...            ...           ...          ...
# 2257             0.0  ...   GENERAL      10th Pass  1.168500e+06       9000.0
# 2258             0.0  ...   GENERAL  Post Graduate  4.890000e+06    1020000.0
# 2259            18.0  ...   GENERAL       Graduate  1.287852e+09   11535000.0
# 2260             0.0  ...   GENERAL  Post Graduate  9.036630e+08          0.0
# 2261             3.0  ...   GENERAL      12th Pass  5.857733e+07    5250000.0
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0            376892           482       377374
# 1            318665           149       318814
# 2            314057           181       314238
# 4            644459          2416       646875
# 5            434199          1130       435329
# ...             ...           ...          ...
# 2257          20563            57        20620
# 2258          14661            25        14686
# 2259         434066           178       434244
# 2260         427900           115       428015
# 2261         138731           216       138947
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0                                 25.330684
# 1                                 21.399929
# 2                                 21.092771
# 4                                 33.383823
# 5                                 22.466390
# ...                                     ...
# 2257                               1.076097
# 2258                               0.766419
# 2259                              28.975369
# 2260                              28.559732
# 2261                               9.271379
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 4                                     56.464615         1937690
# 5                                     37.999125         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
#
# [2018 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with a 'state_label' column
# You can use df['state_label'].value_counts() to get the frequency of each state label

# Get the frequency of each state label
state_label_counts = df['PARTY'].value_counts()

# Extract the state labels (x-axis) and their corresponding frequencies (y-axis)
state_labels = state_label_counts.index
frequencies = state_label_counts.values

# Create a bar plot
plt.figure(figsize=(30, 6))
plt.bar(state_labels, frequencies)
plt.xlabel('Party')
plt.ylabel('Frequency')
plt.title('Frequency of Parties')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability if needed
plt.tight_layout()  # Ensure all labels fit in the plot
plt.show()

# %% [markdown]
# ONE HOT ENCODING for catergory, and dropping symbol

# %%
df_new = pd.get_dummies(df_new, columns=['CATEGORY'], prefix=['CATEGORY'])
df_new=df_new.drop("SYMBOL",axis=1)
df_new
# Out:
#               STATE  state_label     CONSTITUENCY  constituency_label  \
# 0         Telangana           31         ADILABAD                   0
# 1         Telangana           31         ADILABAD                   0
# 2         Telangana           31         ADILABAD                   0
# 4     Uttar Pradesh           33             AGRA                   1
# 5     Uttar Pradesh           33             AGRA                   1
# ...             ...          ...              ...                 ...
# 2257    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2258    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2259      Telangana           31        ZAHIRABAD                 538
# 2260      Telangana           31        ZAHIRABAD                 538
# 2261      Telangana           31        ZAHIRABAD                 538
#
#                         NAME  WINNER     PARTY  GENDER  CRIMINAL CASES   AGE  \
# 0             SOYAM BAPU RAO       1  0.208127    MALE            52.0  52.0
# 1               Godam Nagesh       0  0.008424    MALE             0.0  54.0
# 2              RATHOD RAMESH       0  0.204658    MALE             3.0  52.0
# 4      Satyapal Singh Baghel       1  0.208127    MALE             5.0  58.0
# 5           Manoj Kumar Soni       0  0.080773    MALE             0.0  47.0
# ...                      ...     ...       ...     ...             ...   ...
# 2257  Vaishali Sudhakar Yede       0  0.000496  FEMALE             0.0  28.0
# 2258      Anil Jayram Rathod       0  0.099604    MALE             0.0  43.0
# 2259               B.B.PATIL       1  0.008424    MALE            18.0  63.0
# 2260         MADAN MOHAN RAO       0  0.204658    MALE             0.0  49.0
# 2261      BANALA LAXMA REDDY       0  0.208127    MALE             3.0  47.0
#
#       ... LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0     ...    231450.0         376892           482       377374
# 1     ...    847000.0         318665           149       318814
# 2     ...  15300000.0         314057           181       314238
# 4     ...   8606522.0         644459          2416       646875
# 5     ...  22251891.0         434199          1130       435329
# ...   ...         ...            ...           ...          ...
# 2257  ...      9000.0          20563            57        20620
# 2258  ...   1020000.0          14661            25        14686
# 2259  ...  11535000.0         434066           178       434244
# 2260  ...         0.0         427900           115       428015
# 2261  ...   5250000.0         138731           216       138947
#
#       OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0                                 25.330684
# 1                                 21.399929
# 2                                 21.092771
# 4                                 33.383823
# 5                                 22.466390
# ...                                     ...
# 2257                               1.076097
# 2258                               0.766419
# 2259                              28.975369
# 2260                              28.559732
# 2261                               9.271379
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS  \
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 4                                     56.464615         1937690
# 5                                     37.999125         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
#
#       CATEGORY_GENERAL  CATEGORY_SC  CATEGORY_ST
# 0                    0            0            1
# 1                    0            0            1
# 2                    0            0            1
# 4                    0            1            0
# 5                    0            1            0
# ...                ...          ...          ...
# 2257                 1            0            0
# 2258                 1            0            0
# 2259                 1            0            0
# 2260                 1            0            0
# 2261                 1            0            0
#
# [2018 rows x 22 columns]

# %% [markdown]
# ORDINAL ENCODING for education column and gender

# %%
distinct_values = df_new['EDUCATION'].unique()
distinct_values
# Out:
# array(['12th Pass', 'Post Graduate', 'Doctorate', 'Graduate', 'Others',
#        '10th Pass', '8th Pass', 'Graduate Professional', 'Literate',
#        'Illiterate', '5th Pass', nan, 'Post Graduate\n'], dtype=object)

# %%
education_mapping = {
    '5th Pass': 1,
    "8th Pass": 2,
    "10th Pass": 3,
    '12th Pass': 4,
    'Graduate': 5,
    "Post Graduate": 6,
    "Graduate Professional": 7,
    'Doctorate': 8,
    'Literate': 9,
    "Post Graduate\n": 10,
    "Illiterate": 11,
    'nan': 12,
    "other":13
}
df_new['EDUCATION_ORDERED'] = df_new['EDUCATION'].map(education_mapping)

# %%
import matplotlib.pyplot as plt

# Get the frequency of each state label
state_label_counts = df['EDUCATION'].value_counts()

# Extract the state labels (x-axis) and their corresponding frequencies (y-axis)
state_labels = state_label_counts.index
frequencies = state_label_counts.values

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(state_labels, frequencies)
plt.xlabel('Education')
plt.ylabel('Frequency')
plt.title('Frequency of Education Levels')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability if needed
plt.tight_layout()  # Ensure all labels fit in the plot
plt.show()

# %%
gender_mapping = {
    "MALE":1,
    "fEMALE":2
}
df_new['GENDER_LABELED'] = df_new['GENDER'].map(gender_mapping)
df_new
# Out:
#               STATE  state_label     CONSTITUENCY  constituency_label  \
# 0         Telangana           31         ADILABAD                   0
# 1         Telangana           31         ADILABAD                   0
# 2         Telangana           31         ADILABAD                   0
# 4     Uttar Pradesh           33             AGRA                   1
# 5     Uttar Pradesh           33             AGRA                   1
# ...             ...          ...              ...                 ...
# 2257    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2258    Maharashtra           19  YAVATMAL-WASHIM                 537
# 2259      Telangana           31        ZAHIRABAD                 538
# 2260      Telangana           31        ZAHIRABAD                 538
# 2261      Telangana           31        ZAHIRABAD                 538
#
#                         NAME  WINNER     PARTY  GENDER  CRIMINAL CASES   AGE  \
# 0             SOYAM BAPU RAO       1  0.208127    MALE            52.0  52.0
# 1               Godam Nagesh       0  0.008424    MALE             0.0  54.0
# 2              RATHOD RAMESH       0  0.204658    MALE             3.0  52.0
# 4      Satyapal Singh Baghel       1  0.208127    MALE             5.0  58.0
# 5           Manoj Kumar Soni       0  0.080773    MALE             0.0  47.0
# ...                      ...     ...       ...     ...             ...   ...
# 2257  Vaishali Sudhakar Yede       0  0.000496  FEMALE             0.0  28.0
# 2258      Anil Jayram Rathod       0  0.099604    MALE             0.0  43.0
# 2259               B.B.PATIL       1  0.008424    MALE            18.0  63.0
# 2260         MADAN MOHAN RAO       0  0.204658    MALE             0.0  49.0
# 2261      BANALA LAXMA REDDY       0  0.208127    MALE             3.0  47.0
#
#       ... POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0     ...          482       377374                              25.330684
# 1     ...          149       318814                              21.399929
# 2     ...          181       314238                              21.092771
# 4     ...         2416       646875                              33.383823
# 5     ...         1130       435329                              22.466390
# ...   ...          ...          ...                                    ...
# 2257  ...           57        20620                               1.076097
# 2258  ...           25        14686                               0.766419
# 2259  ...          178       434244                              28.975369
# 2260  ...          115       428015                              28.559732
# 2261  ...          216       138947                               9.271379
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS  \
# 0                                     35.468248         1489790
# 1                                     29.964370         1489790
# 2                                     29.534285         1489790
# 4                                     56.464615         1937690
# 5                                     37.999125         1937690
# ...                                         ...             ...
# 2257                                   1.755157         1916185
# 2258                                   1.250060         1916185
# 2259                                  41.574183         1498666
# 2260                                  40.977823         1498666
# 2261                                  13.302678         1498666
#
#       CATEGORY_GENERAL  CATEGORY_SC  CATEGORY_ST  EDUCATION_ORDERED  \
# 0                    0            0            1                4.0
# 1                    0            0            1                6.0
# 2                    0            0            1                4.0
# 4                    0            1            0                8.0
# 5                    0            1            0                6.0
# ...                ...          ...          ...                ...
# 2257                 1            0            0                3.0
# 2258                 1            0            0                6.0
# 2259                 1            0            0                5.0
# 2260                 1            0            0                6.0
# 2261                 1            0            0                4.0
#
#       GENDER_LABELED
# 0                1.0
# 1                1.0
# 2                1.0
# 4                1.0
# 5                1.0
# ...              ...
# 2257             NaN
# 2258             1.0
# 2259             1.0
# 2260             1.0
# 2261             1.0
#
# [2018 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with a 'state_label' column
# You can use df['state_label'].value_counts() to get the frequency of each state label

# Get the frequency of each state label
state_label_counts = df['GENDER'].value_counts()

# Extract the state labels (x-axis) and their corresponding frequencies (y-axis)
state_labels = state_label_counts.index
frequencies = state_label_counts.values

# Create a bar plot
plt.figure(figsize=(5, 3))
plt.bar(state_labels, frequencies)
plt.xlabel('GENDER')
plt.ylabel('Frequency')
plt.title('Frequency of Gender')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability if needed
plt.tight_layout()  # Ensure all labels fit in the plot
plt.show()

# %% [markdown]
# DATA DISCRETIZATION

# %%
from sklearn.cluster import KMeans
import numpy as np


# Extract the column you want to discretize
total_electors = df_new[['TOTAL ELECTORS']]

# Specify the number of clusters (K) for K-Means discretization
n_clusters = 10  # You can adjust this value as needed

# Apply K-Means clustering to discretize the column
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(total_electors)
df_new['total_electors_discretized'] = kmeans.predict(total_electors)

# Plot a histogram to visualize the discretization
plt.figure(figsize=(8, 6))
plt.hist(df_new['TOTAL ELECTORS'], bins=20, alpha=0.5, label='Original')
plt.xlabel('Total Electors')
plt.ylabel('Frequency')
plt.title('K-Means Discretization of Total Electors')
plt.legend()
plt.show()

# Plot a histogram to visualize the discretization
plt.figure(figsize=(8, 6))
plt.hist(df_new['total_electors_discretized'], bins=20, alpha=0.5, label='Discretized')
plt.xlabel('Total Electors')
plt.ylabel('Frequency')
plt.title('K-Means Discretization of Total Electors')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeClassifier

assets = df_new[['AGE']]
max_leaf_nodes = 10  # You can adjust this value as needed
decision_tree = DecisionTreeClassifier(max_leaf_nodes=max_leaf_nodes)
decision_tree.fit(assets, assets)
df_new['assets_discretized'] = decision_tree.apply(assets)

plt.figure(figsize=(8, 6))
plt.hist(df_new[['AGE']], bins=20, alpha=0.5, label='Original')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Decision Tree Discretization of Age')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.hist(df_new['assets_discretized'], bins=20, alpha=0.5, label='Discretized')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Decision Tree Discretization of Age')
plt.legend()
plt.show()

# %%
bin_boundaries = decision_tree.tree_.threshold

# Define age group labels based on bin boundaries
age_groups = []
previous_boundary = float('-inf')  # Start with negative infinity as the first boundary
for boundary in bin_boundaries:
    age_group_label = f"Ages {float(previous_boundary)+1}-{float(boundary)}"
    age_groups.append(age_group_label)
    previous_boundary = boundary

# Add the last age group (from the last boundary to positive infinity)
age_groups.append(f"Ages {float(bin_boundaries[-1])+1}+")

# Print the age groups and their corresponding bin boundaries
for i, age_group in enumerate(age_groups):
    print(f"Bin {i}: {age_group}")
# Out:
# Bin 0: Ages -inf-54.5
# Bin 1: Ages 55.5-51.5
# Bin 2: Ages 52.5-55.5
# Bin 3: Ages 56.5--2.0
# Bin 4: Ages -1.0-56.5
# Bin 5: Ages 57.5--2.0
# Bin 6: Ages -1.0-58.5
# Bin 7: Ages 59.5--2.0
# Bin 8: Ages -1.0-52.5
# Bin 9: Ages 53.5--2.0
# Bin 10: Ages -1.0--2.0
# Bin 11: Ages -1.0-57.5
# Bin 12: Ages 58.5-59.5
# Bin 13: Ages 60.5--2.0
# Bin 14: Ages -1.0-61.5
# Bin 15: Ages 62.5--2.0
# Bin 16: Ages -1.0--2.0
# Bin 17: Ages -1.0--2.0
# Bin 18: Ages -1.0--2.0
# Bin 19: Ages -1.0+

# %% [markdown]
# OUTLIER HANDLING

# %%
sns.boxplot( y='AGE',data=df_new)
# Out:
# <Axes: ylabel='AGE'>

# %%
sns.boxplot( y='TOTAL VOTES',data=df_new)
# Out:
# <Axes: ylabel='TOTAL VOTES'>

# %%
sns.boxplot( y='TOTAL ELECTORS',data=df_new)
# Out:
# <Axes: ylabel='TOTAL ELECTORS'>

# %% [markdown]
# malkajgiri has 31lakh electors, it is an outlier

# %% [markdown]
# OUTLIER CAPPING

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
column_name = "TOTAL ELECTORS"

Q1 = df_new[column_name].quantile(0.25)
Q3 = df_new[column_name].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_new[column_name] = df_new[column_name].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

plt.figure(figsize=(4, 6))
sns.boxplot(y=df_new[column_name], orient="v")
plt.title(f"Boxplot of {column_name} (After Outlier Capping)")
plt.ylabel(column_name)
plt.show()

# %% [markdown]
# FEATURE SCALING

# %% [markdown]
# 1)Feature selection using chi-squared

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.impute import SimpleImputer

# Assuming you have a DataFrame named 'df_new'

df1 = df_new.copy()

# Remove non-numeric columns that shouldn't be used for feature selection
df1 = df1.drop(columns=["WINNER", "STATE", "CONSTITUENCY", "GENDER", "NAME", "EDUCATION"])

imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(df1)

y = df_new["WINNER"]  # Target variable

num_features_to_select = 10

bestfeatures = SelectKBest(score_func=chi2, k=num_features_to_select)
fit = bestfeatures.fit(X_imputed, y)

# Get the selected features and their scores
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(df1.columns)
featureScores = pd.concat([dfcolumns, dfscores], axis=1)
featureScores.columns = ['Specs', 'Score']
featureScores = featureScores.sort_values(by='Score', ascending=False)
selected_features = featureScores.head(num_features_to_select)
print("Selected Features:")
print(selected_features)

# Plot the graph of feature scores
plt.figure(figsize=(10, 6))
plt.bar(selected_features['Specs'], selected_features['Score'])
plt.title('Chi-squared Test Scores for Feature Selection')
plt.xlabel('Features')
plt.ylabel('Chi-squared Score')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# Selected Features:
#                                         Specs         Score
# 5                                      ASSETS  3.172663e+10
# 6                                 LIABILITIES  9.414698e+09
# 9                                 TOTAL VOTES  2.304589e+08
# 7                               GENERAL VOTES  2.292337e+08
# 8                                POSTAL VOTES  1.261312e+06
# 12                             TOTAL ELECTORS  1.187970e+05
# 11  OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  2.013616e+04
# 10      OVER TOTAL ELECTORS \nIN CONSTITUENCY  1.351904e+04
# 3                              CRIMINAL CASES  9.648726e+01
# 1                          constituency_label  7.706853e+01

# %% [markdown]
# 2) CORRELATION MATRIX WITH HEATMAP

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Select the top 10 features from the DataFrame
selected_columns = selected_features['Specs'].tolist()
selected_columns.append("WINNER")  # Add the target variable if needed

df_selected = df_new[selected_columns]

# Calculate the correlation matrix
correlation_matrix = df_selected.corr()

# Set up the matplotlib figure
plt.figure(figsize=(7, 5))

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)

plt.title("Correlation Matrix Heatmap")
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Show the heatmap
plt.show()

# %% [markdown]
# TRANSFORMATION

# %% [markdown]
# Z-Score transformation on ASSETS, LIABILITES, TOTAL VOTES, TOTAL ELECTORS

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Assuming you have a DataFrame named 'df_new' with columns: "ASSETS", "LIABILITIES", "TOTAL VOTES", and "TOTAL ELECTORS"

# Select the columns to be transformed
columns_to_transform = ["ASSETS", "LIABILITIES", "TOTAL VOTES", "TOTAL ELECTORS"]

# Z-score transformation
zscore_scaler = StandardScaler()
df_new_zscore = df_new.copy()
df_new_zscore[columns_to_transform] = zscore_scaler.fit_transform(df_new_zscore[columns_to_transform])

# Min-Max normalization
minmax_scaler = MinMaxScaler()
df_new_minmax = df_new.copy()
df_new_minmax[columns_to_transform] = minmax_scaler.fit_transform(df_new_minmax[columns_to_transform])

# Plot before normalization graphs
plt.figure(figsize=(12, 6))
for i, column in enumerate(columns_to_transform):
    plt.subplot(2, 2, i + 1)
    plt.hist(df_new[column], bins=20, alpha=0.5, color='b')
    plt.title(f'Before Normalization - {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Plot Z-score transformation graphs
plt.figure(figsize=(12, 6))
for i, column in enumerate(columns_to_transform):
    plt.subplot(2, 2, i + 1)
    plt.hist(df_new_zscore[column], bins=20, alpha=0.5, color='r')
    plt.title(f'Z-score Transformation - {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Plot Min-Max normalization graphs
plt.figure(figsize=(12, 6))
for i, column in enumerate(columns_to_transform):
    plt.subplot(2, 2, i + 1)
    plt.hist(df_new_minmax[column], bins=20, alpha=0.5, color='g')
    plt.title(f'Min-Max Normalization - {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
